# %% [markdown]
# Upload datatab

# %%
#modules
import pandas as pd
import numpy as np
from pages import utils
#read data
data = pd.read_csv("attrition.csv")
# Collect the categorical and numerical columns      
numeric_cols = data.select_dtypes(include=np.number).columns.tolist()
categorical_cols = list(set(list(data.columns)) - set(numeric_cols))
        
data.head()
# Out:
#    Unnamed: 0  Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0           1    2001                0.58             0.74               4
# 1           2    2002                0.82             0.67               2
# 2           3    2003                0.45             0.69               5
# 3           4    2004                0.78             0.82               5
# 4           5    2005                0.49             0.60               3
#
#    average_montly_hours  time_spend_company  Work_accident  \
# 0                   215                   3              0
# 1                   202                   3              0
# 2                   193                   3              0
# 3                   247                   3              0
# 4                   214                   2              0
#
#    promotion_last_5years   dept salary status
# 0                      0  sales    low  exist
# 1                      0  sales    low  exist
# ...

# %%
print(numeric_cols)
print(categorical_cols)
# Out:
# ['Emp ID', 'satisfaction_level', 'last_evaluation', 'number_project', 'average_montly_hours', 'time_spend_company', 'Work_accident', 'promotion_last_5years']
# ['salary', 'dept', 'status']

# %%
data.dtypes
# Out:
# dtype('int64')

# %%
a = 0

def indexer(x):
    if

# %%
data.select_dtypes(include=np.number).columns.tolist()
# Out:
# ['Unnamed: 0',
#  'satisfaction_level',
#  'last_evaluation',
#  'number_project',
#  'average_montly_hours',
#  'time_spend_company',
#  'Work_accident',
#  'promotion_last_5years']

# %% [markdown]
# Function to return the datatypes and the corresponding column names

# %%
def get_types(dataframe):

    #empty dictionary
    df_types = dataframe.dtypes
    
    #Get columns
    df_cols = dataframe.columns

    #empty dict
    cols_types = {}

    for cols, types in zip(df_cols, df_types):
            if types in ["int64", "float64"]:
                cols_types[cols] = "numerical"
            else:
                 cols_types[cols] = "categorical"
    
    result = pd.DataFrame(cols_types, index = [0]).transpose().reset_index().rename(columns = {"index" : "column_name", 0  : "type"})
    return result

# %%
columns_df = get_types(data)#.shape[0]
columns_df
# Out:
#               column_name         type
# 0              Unnamed: 0    numerical
# 1      satisfaction_level    numerical
# 2         last_evaluation    numerical
# 3          number_project    numerical
# 4    average_montly_hours    numerical
# 5      time_spend_company    numerical
# 6           Work_accident    numerical
# 7   promotion_last_5years    numerical
# 8                    dept  categorical
# 9                  salary  categorical
# 10                 status  categorical

# %%
categorical_cols = list(set(list(data.columns)) - set(numeric_cols))
categorical_cols
# Out:
# ['salary', 'dept', 'status']

# %%
# Save the columns as a dataframe or dictionary
columns = []

# Iterate through the numerical and categorical columns and save in columns 
col_metadata = get_types(data) 

col_metadata
# Out:
#               column_name         type
# 0              Unnamed: 0    numerical
# 1                  Emp ID    numerical
# 2      satisfaction_level    numerical
# 3         last_evaluation    numerical
# 4          number_project    numerical
# 5    average_montly_hours    numerical
# 6      time_spend_company    numerical
# 7           Work_accident    numerical
# 8   promotion_last_5years    numerical
# 9                    dept  categorical
# 10                 salary  categorical
# 11                 status  categorical

# %%
   
# Save the columns as a dataframe with categories
# Here column_name is the name of the field and the type is whether it's numerical or categorical
columns_df = pd.DataFrame(columns, columns = ['column_name', 'type'])
columns_df.to_csv('data/metadata/column_type_desc.csv', index = False)

# %%
name = "Emp ID"
# Design column two 
current_type = col_metadata[col_metadata['column_name'] == name]['type'].values[0]
current_type
# Out:
# 'numerical'

# %%
column_options = ['numeric', 'categorical','object']
current_index = column_options.index(current_type)

# %%
data.drop("Emp ID", axis = 1)
# Out:
#        Unnamed: 0  satisfaction_level  last_evaluation  number_project  \
# 0               1                0.58             0.74               4
# 1               2                0.82             0.67               2
# 2               3                0.45             0.69               5
# 3               4                0.78             0.82               5
# 4               5                0.49             0.60               3
# ...           ...                 ...              ...             ...
# 14994       14995                0.40             0.57               2
# 14995       14996                0.37             0.48               2
# 14996       14997                0.37             0.53               2
# 14997       14998                0.11             0.96               6
# 14998       14999                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  \
# ...

# %%
import os 
os.listdir('data')

x = 1

if
# Out:
#   File "<ipython-input-62-87cc82686a69>", line 7
#     return "a"
#     ^
# SyntaxError: 'return' outside function

# %%
import streamlit as st
import numpy as np
import pandas as pd
from pages import utils
import matplotlib.pyplot as plt
import seaborn as sns
import os

#decide what data to visualize
#create drop now to show whether to use the old data or new

def app():
    st.write("Choose the Dataset to be visualize")
    data_vis = st.selectbox("Which dataset do you want to visualize", options = ["main_data", "new_main_data"])
    
    
    
    #if data is not found att all
    if (data_vis + ".csv") not in os.listdir('data'):
        st.markdown("Please upload data through `Upload Data` page!")
    else:
        # df_analysis = pd.read_csv('data/2015.csv')
        #create data input variable
        read = "data/"+ data_vis + ".csv"
        df_analysis = pd.read_csv(read)
        # df_visual = pd.DataFrame(df_analysis)
        df_visual = df_analysis.copy()
        
        #meta data
        
        cols = pd.read_csv(meta_read)
        Categorical,Numerical,Object = utils.getColumnTypes(cols)
        cat_groups = {}
        unique_Category_val={}

        for i in range(len(Categorical)):
                unique_Category_val = {Categorical[i]: utils.mapunique(df_analysis, Categorical[i])}
                cat_groups = {Categorical[i]: df_visual.groupby(Categorical[i])}
                
        
        category = st.selectbox("Select Category ", Categorical + Object)

        sizes = (df_visual[category].value_counts()/df_visual[category].count())

        labels = sizes.keys()

        maxIndex = np.argmax(np.array(sizes))
        explode = [0]*len(labels)
        explode[int(maxIndex)] = 0.1
        explode = tuple(explode)
        
        fig1, ax1 = plt.subplots()
        ax1.pie(sizes,explode = explode, labels=labels, autopct='%1.1f%%',shadow=False, startangle=0)
        ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
        ax1.set_title('Distribution for Categorical Column - ' + (str)(category))
        st.pyplot(fig1)
        
        corr = df_analysis.corr(method='pearson')
        
        fig2, ax2 = plt.subplots()
        mask = np.zeros_like(corr, dtype=np.bool)
        mask[np.triu_indices_from(mask)] = True
        # Colors
        cmap = sns.diverging_palette(240, 10, as_cmap=True)
        sns.heatmap(corr, mask=mask, linewidths=.5, cmap=cmap, center=0,ax=ax2)
        ax2.set_title("Correlation Matrix")
        st.pyplot(fig2)
        
        
        categoryObject=st.selectbox("Select " + (str)(category),unique_Category_val[category])
        st.write(cat_groups[category].get_group(categoryObject).describe())
        colName = st.selectbox("Select Column ",Numerical)

        st.bar_chart(cat_groups[category].get_group(categoryObject)[colName])
        
        ## Code base to drop redundent columns

# %%
from pages import utils
df_analysis = pd.read_csv(r"C:\Users\SIMIYOUNG\Documents\Python-Projects\streamlit\data-storyteller-main\data\main_data.csv")
# df_visual = pd.DataFrame(df_analysis)
df_visual = df_analysis.copy()
cols = pd.read_csv(r"C:\Users\SIMIYOUNG\Documents\Python-Projects\streamlit\data-storyteller-main\data\metadata\column_type_desc.csv")
Categorical,Numerical,Object = utils.getColumnTypes(cols)
cat_groups = {}
unique_Category_val={}

for i in range(len(Categorical)):
        unique_Category_val = {Categorical[i]: utils.mapunique(df_analysis, Categorical[i])}
        cat_groups = {Categorical[i]: df_visual.groupby(Categorical[i])}

# %%
# Out:
# ['satisfaction_level',
#  'last_evaluation',
#  'number_project',
#  'average_montly_hours',
#  'time_spend_company',
#  'Work_accident',
#  'promotion_last_5years',
#  'dept',
#  'salary',
#  'status']

# %%
category = Categorical + Object

sizes = (df_visual[category].value_counts()/df_visual[category].count())

labels = sizes.keys()

maxIndex = np.argmax(np.array(sizes))
explode = [0]*len(labels)
explode[int(maxIndex)] = 0.1
explode = tuple(explode)

fig1, ax1 = plt.subplots()
ax1.pie(sizes,explode = explode, labels=labels, autopct='%1.1f%%',shadow=False, startangle=0)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
ax1.set_title('Distribution for Categorical Column - ' + (str)(category))
st.pyplot(fig1)

corr = df_analysis.corr(method='pearson')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-843f16418849> in <module>
#       1 category = Categorical + Object
#       2
# ----> 3 sizes = (df_visual[category].value_counts()/df_visual[category].count())
#       4
#       5 labels = sizes.keys()
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~\anaconda3\lib\site-packages\pandas\core\arraylike.py in __truediv__(self, other)
#     111     @unpack_zerodim_and_defer("__truediv__")
#     112     def __truediv__(self, other):
# --> 113         return self._arith_method(other, operator.truediv)
#     114
#     115     @unpack_zerodim_and_defer("__rtruediv__")
#
# ...

# %%
Categorical + Object

# %%
 #decide whic meta data is to be read in when data to be visualized is chosen
if data_vis == "main_data":
    meta_read = r"data/metadata/column_type_desc.csv"
else:
    meta_read = r"data/metadata/new_column_type_desc.csv"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-bfd5dbe5bed9> in <module>
#       1 #decide whic meta data is to be read in when data to be visualized is chosen
# ----> 2 if data_vis == "main_data":
#       3    meta_read = r"data/metadata/column_type_desc.csv"
#       4 else:
#       5    meta_read = r"data/metadata/new_column_type_desc.csv"
#
# NameError: name 'data_vis' is not defined

# %%
df_analysis["status"].hist()
# Out:
# <AxesSubplot:>
